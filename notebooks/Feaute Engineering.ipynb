# %% [markdown]
# #Feaute Engineering

# %%
import pandas as pd
import numpy as np

df=pd.read_csv('../data/Housing_Data-set.csv')
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
#    yr_renovated                    street       city  statezip country
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0           709 W Blaine St    Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042     USA
# 3             0           857 170th Pl NE   Bellevue  WA 98008     USA
# 4          1992         9105 170th Ave NE    Redmond  WA 98052     USA

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='str')

# %%
df['House_age']=2025-df['yr_built']
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
#    yr_renovated                    street       city  statezip country  \
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0           709 W Blaine St    Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042     USA
# 3             0           857 170th Pl NE   Bellevue  WA 98008     USA
# 4          1992         9105 170th Ave NE    Redmond  WA 98052     USA
#
#    House_age
# 0         70
# 1        104
# 2         59
# 3         62
# 4         49

# %%
df['Age_of_renovation'] = np.where(df['yr_renovated'] > 0, 2025 - df['yr_renovated'], 0)
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
#    yr_renovated                    street       city  statezip country  \
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0           709 W Blaine St    Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042     USA
# 3             0           857 170th Pl NE   Bellevue  WA 98008     USA
# 4          1992         9105 170th Ave NE    Redmond  WA 98052     USA
#
#    House_age  Age_of_renovation
# 0         70                 20
# 1        104                  0
# 2         59                  0
# 3         62                  0
# 4         49                 33

# %%
df['total_area']=df['sqft_living']+df['sqft_lot']
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  ...  sqft_basement  yr_built  \
# 0     1.5           0     0          3  ...              0      1955
# 1     2.0           0     4          5  ...            280      1921
# 2     1.0           0     0          4  ...              0      1966
# 3     1.0           0     0          4  ...           1000      1963
# 4     1.0           0     0          4  ...            800      1976
#
#    yr_renovated                    street       city  statezip country  \
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0           709 W Blaine St    Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042     USA
# 3             0           857 170th Pl NE   Bellevue  WA 98008     USA
# 4          1992         9105 170th Ave NE    Redmond  WA 98052     USA
#
#   House_age  Age_of_renovation  total_area
# 0        70                 20        9252
# 1       104                  0       12700
# 2        59                  0       13877
# 3        62                  0       10030
# 4        49                 33       12440
#
# [5 rows x 21 columns]

# %%
#BRB--> Bedrooms to bathrooms
df['BRB']=df['bedrooms']/df['bathrooms']
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  ...  yr_built  yr_renovated  \
# 0     1.5           0     0          3  ...      1955          2005
# 1     2.0           0     4          5  ...      1921             0
# 2     1.0           0     0          4  ...      1966             0
# 3     1.0           0     0          4  ...      1963             0
# 4     1.0           0     0          4  ...      1976          1992
#
#                      street       city  statezip country House_age  \
# 0      18810 Densmore Ave N  Shoreline  WA 98133     USA        70
# 1           709 W Blaine St    Seattle  WA 98119     USA       104
# 2  26206-26214 143rd Ave SE       Kent  WA 98042     USA        59
# 3           857 170th Pl NE   Bellevue  WA 98008     USA        62
# 4         9105 170th Ave NE    Redmond  WA 98052     USA        49
#
#   Age_of_renovation  total_area       BRB
# 0                20        9252  2.000000
# 1                 0       12700  2.000000
# 2                 0       13877  1.500000
# 3                 0       10030  1.333333
# 4                33       12440  1.600000
#
# [5 rows x 22 columns]

# %%
df['renovated']=np.where(df.Age_of_renovation>0,1,0)
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  ...  yr_renovated  \
# 0     1.5           0     0          3  ...          2005
# 1     2.0           0     4          5  ...             0
# 2     1.0           0     0          4  ...             0
# 3     1.0           0     0          4  ...             0
# 4     1.0           0     0          4  ...          1992
#
#                      street       city  statezip country House_age  \
# 0      18810 Densmore Ave N  Shoreline  WA 98133     USA        70
# 1           709 W Blaine St    Seattle  WA 98119     USA       104
# 2  26206-26214 143rd Ave SE       Kent  WA 98042     USA        59
# 3           857 170th Pl NE   Bellevue  WA 98008     USA        62
# 4         9105 170th Ave NE    Redmond  WA 98052     USA        49
#
#   Age_of_renovation total_area       BRB  renovated
# 0                20       9252  2.000000          1
# 1                 0      12700  2.000000          0
# 2                 0      13877  1.500000          0
# 3                 0      10030  1.333333          0
# 4                33      12440  1.600000          1
#
# [5 rows x 23 columns]

# %%
import seaborn as sns

corr = df.corr(numeric_only=True)
corr

sns.heatmap(corr)
# Out:
# <Axes: >

# %%
print(df["price"].describe())
# Out:
# count    4.600000e+03
# mean     5.519630e+05
# std      5.638347e+05
# min      0.000000e+00
# 25%      3.228750e+05
# 50%      4.609435e+05
# 75%      6.549625e+05
# max      2.659000e+07
# Name: price, dtype: float64
